# %%
pip install pytesseract opencv-python pandas openpyxl
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: pytesseract in c:\users\jyoth\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (0.3.13)
# Requirement already satisfied: opencv-python in c:\users\jyoth\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (4.11.0.86)
# Requirement already satisfied: pandas in c:\users\jyoth\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (2.2.3)
# Requirement already satisfied: openpyxl in c:\users\jyoth\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (3.1.5)
# Requirement already satisfied: packaging>=21.3 in c:\users\jyoth\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from pytesseract) (24.2)
# Requirement already satisfied: Pillow>=8.0.0 in c:\users\jyoth\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from pytesseract) (11.1.0)
# Requirement already satisfied: numpy>=1.21.2 in c:\users\jyoth\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from opencv-python) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\jyoth\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\jyoth\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from pandas) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\jyoth\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from pandas) (2025.1)
# Requirement already satisfied: et-xmlfile in c:\users\jyoth\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from openpyxl) (2.0.0)
# Requirement already satisfied: six>=1.5 in c:\users\jyoth\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
# !pip install keras-ocr
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: keras-ocr in c:\users\jyoth\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (0.9.3)
# Requirement already satisfied: editdistance in c:\users\jyoth\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from keras-ocr) (0.8.1)
# Requirement already satisfied: efficientnet==1.0.0 in c:\users\jyoth\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from keras-ocr) (1.0.0)
# Requirement already satisfied: essential_generators in c:\users\jyoth\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from keras-ocr) (1.0)
# Requirement already satisfied: fonttools in c:\users\jyoth\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from keras-ocr) (4.56.0)
# Requirement already satisfied: imgaug in c:\users\jyoth\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from keras-ocr) (0.4.0)
# Requirement already satisfied: pyclipper in c:\users\jyoth\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from keras-ocr) (1.3.0.post6)
# Requirement already satisfied: shapely in c:\users\jyoth\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from keras-ocr) (2.0.7)
# Requirement already satisfied: tqdm in c:\users\jyoth\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from keras-ocr) (4.67.1)
# Requirement already satisfied: validators in c:\users\jyoth\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from keras-ocr) (0.34.0)
# Requirement already satisfied: keras-applications<=1.0.8,>=1.0.7 in c:\users\jyoth\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from efficientnet==1.0.0->keras-ocr) (1.0.8)
# Requirement already satisfied: scikit-image in c:\users\jyoth\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from efficientnet==1.0.0->keras-ocr) (0.25.2)
# Requirement already satisfied: six in c:\users\jyoth\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from imgaug->keras-ocr) (1.17.0)
# Requirement already satisfied: numpy>=1.15 in c:\users\jyoth\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from imgaug->keras-ocr) (1.26.4)
# Requirement already satisfied: scipy in c:\users\jyoth\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from imgaug->keras-ocr) (1.15.2)
# Requirement already satisfied: Pillow in c:\users\jyoth\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from imgaug->keras-ocr) (11.1.0)
# Requirement already satisfied: matplotlib in c:\users\jyoth\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from imgaug->keras-ocr) (3.10.1)
# Requirement already satisfied: opencv-python in c:\users\jyoth\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from imgaug->keras-ocr) (4.11.0.86)
# Requirement already satisfied: imageio in c:\users\jyoth\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from imgaug->keras-ocr) (2.37.0)
# Requirement already satisfied: colorama in c:\users\jyoth\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from tqdm->keras-ocr) (0.4.6)
# Requirement already satisfied: h5py in c:\users\jyoth\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from keras-applications<=1.0.8,>=1.0.7->efficientnet==1.0.0->keras-ocr) (3.13.0)
# Requirement already satisfied: networkx>=3.0 in c:\users\jyoth\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from scikit-image->efficientnet==1.0.0->keras-ocr) (3.4.2)
# Requirement already satisfied: tifffile>=2022.8.12 in c:\users\jyoth\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from scikit-image->efficientnet==1.0.0->keras-ocr) (2025.2.18)
# Requirement already satisfied: packaging>=21 in c:\users\jyoth\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from scikit-image->efficientnet==1.0.0->keras-ocr) (24.2)
# Requirement already satisfied: lazy-loader>=0.4 in c:\users\jyoth\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from scikit-image->efficientnet==1.0.0->keras-ocr) (0.4)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\jyoth\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from matplotlib->imgaug->keras-ocr) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\jyoth\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from matplotlib->imgaug->keras-ocr) (0.12.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\jyoth\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from matplotlib->imgaug->keras-ocr) (1.4.8)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\jyoth\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from matplotlib->imgaug->keras-ocr) (3.2.1)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\jyoth\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from matplotlib->imgaug->keras-ocr) (2.9.0.post0)

# %%
# Basic libraries.
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import cv2
from PIL import Image
import re

# OCR libraries.
import pytesseract
from pytesseract import Output
# !pip install keras_ocr
import keras_ocr
from keras_ocr.detection import Detector
from keras_ocr.recognition import Recognizer
from keras_ocr import pipeline

# XML reader.
import xml.etree.ElementTree as ET
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: keras_ocr in c:\users\jyoth\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (0.9.3)
# Requirement already satisfied: editdistance in c:\users\jyoth\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from keras_ocr) (0.8.1)
# Requirement already satisfied: efficientnet==1.0.0 in c:\users\jyoth\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from keras_ocr) (1.0.0)
# Requirement already satisfied: essential_generators in c:\users\jyoth\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from keras_ocr) (1.0)
# Requirement already satisfied: fonttools in c:\users\jyoth\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from keras_ocr) (4.56.0)
# Requirement already satisfied: imgaug in c:\users\jyoth\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from keras_ocr) (0.4.0)
# Requirement already satisfied: pyclipper in c:\users\jyoth\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from keras_ocr) (1.3.0.post6)
# Requirement already satisfied: shapely in c:\users\jyoth\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from keras_ocr) (2.0.7)
# Requirement already satisfied: tqdm in c:\users\jyoth\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from keras_ocr) (4.67.1)
# Requirement already satisfied: validators in c:\users\jyoth\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from keras_ocr) (0.34.0)
# Requirement already satisfied: keras-applications<=1.0.8,>=1.0.7 in c:\users\jyoth\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from efficientnet==1.0.0->keras_ocr) (1.0.8)
# Requirement already satisfied: scikit-image in c:\users\jyoth\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from efficientnet==1.0.0->keras_ocr) (0.25.2)
# Requirement already satisfied: six in c:\users\jyoth\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from imgaug->keras_ocr) (1.17.0)
# Requirement already satisfied: numpy>=1.15 in c:\users\jyoth\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from imgaug->keras_ocr) (1.26.4)
# Requirement already satisfied: scipy in c:\users\jyoth\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from imgaug->keras_ocr) (1.15.2)
# Requirement already satisfied: Pillow in c:\users\jyoth\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from imgaug->keras_ocr) (11.1.0)
# Requirement already satisfied: matplotlib in c:\users\jyoth\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from imgaug->keras_ocr) (3.10.1)
# Requirement already satisfied: opencv-python in c:\users\jyoth\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from imgaug->keras_ocr) (4.11.0.86)
# Requirement already satisfied: imageio in c:\users\jyoth\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from imgaug->keras_ocr) (2.37.0)
# Requirement already satisfied: colorama in c:\users\jyoth\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from tqdm->keras_ocr) (0.4.6)
# Requirement already satisfied: h5py in c:\users\jyoth\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from keras-applications<=1.0.8,>=1.0.7->efficientnet==1.0.0->keras_ocr) (3.13.0)
# Requirement already satisfied: networkx>=3.0 in c:\users\jyoth\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from scikit-image->efficientnet==1.0.0->keras_ocr) (3.4.2)
# Requirement already satisfied: tifffile>=2022.8.12 in c:\users\jyoth\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from scikit-image->efficientnet==1.0.0->keras_ocr) (2025.2.18)
# Requirement already satisfied: packaging>=21 in c:\users\jyoth\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from scikit-image->efficientnet==1.0.0->keras_ocr) (24.2)
# Requirement already satisfied: lazy-loader>=0.4 in c:\users\jyoth\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from scikit-image->efficientnet==1.0.0->keras_ocr) (0.4)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\jyoth\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from matplotlib->imgaug->keras_ocr) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\jyoth\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from matplotlib->imgaug->keras_ocr) (0.12.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\jyoth\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from matplotlib->imgaug->keras_ocr) (1.4.8)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\jyoth\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from matplotlib->imgaug->keras_ocr) (3.2.1)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\jyoth\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from matplotlib->imgaug->keras_ocr) (2.9.0.post0)

# %%
# Path to Tesseract OCR executable (Modify this based on your system)
pytesseract.pytesseract.tesseract_cmd = r'C:\Program Files\Tesseract-OCR\tesseract.exe'

# %%
import os
import cv2
import re
import pandas as pd
import pytesseract

# Define the image folder path
IMAGE_FOLDER = r"C:\Users\jyoth\Desktop\Adaptive_Schema_Extraction\DATASET\STAGE 1 DATASET\receipts_img"

# Store names to prioritize (add more as needed)
STORE_NAMES = ["WALMART", "TRADER JOE'S", "COSTCO", "TARGET", "KROGER", "WHOLE FOODS"]

# Function to preprocess image for better OCR
def preprocess_image(image_path):
    image = cv2.imread(image_path, cv2.IMREAD_GRAYSCALE)
    blurred = cv2.GaussianBlur(image, (5, 5), 0)
    thresh = cv2.adaptiveThreshold(blurred, 255, cv2.ADAPTIVE_THRESH_GAUSSIAN_C, cv2.THRESH_BINARY, 31, 2)
    return thresh

# Function to extract text from an image
def extract_text(image_path):
    processed_img = preprocess_image(image_path)
    text = pytesseract.image_to_string(processed_img, config='--psm 6')
    return text

# Function to extract store name
def extract_store_name(text):
    for store in STORE_NAMES:
        if re.search(store, text, re.IGNORECASE):
            return store
    lines = text.split("\n")
    for line in lines:
        clean_line = re.sub(r'[^a-zA-Z0-9 &]', '', line).strip()
        if clean_line and len(clean_line) > 3:
            return clean_line
    return "Not Found"

# Function to extract date
def extract_date(text):
    date_patterns = [
        r"\b\d{1,2}[-/]\d{1,2}[-/]\d{2,4}\b",  # 12/31/2023 or 31-12-23
        r"\b\d{4}-\d{2}-\d{2}\b",  # 2023-12-31
        r"\b\d{2}[.]\d{2}[.]\d{2,4}\b"  # 12.31.23 or 31.12.2023
    ]
    for pattern in date_patterns:
        match = re.search(pattern, text)
        if match:
            return match.group()
    return "Not Found"

# Function to extract total amount
def extract_total_amount(text):
    amount_pattern = r"\b\d{1,4}\.\d{2}\b"
    amounts = re.findall(amount_pattern, text)
    return max(amounts, key=float) if amounts else "Not Found"

# Process all images
receipt_data = []
for filename in os.listdir(IMAGE_FOLDER):
    if filename.lower().endswith((".png", ".jpg", ".jpeg")):
        image_path = os.path.join(IMAGE_FOLDER, filename)
        text = extract_text(image_path)

        store_name = extract_store_name(text)
        date = extract_date(text)
        total_amount = extract_total_amount(text)

        receipt_data.append([filename, store_name, date, total_amount])

# Save results to Excel
df = pd.DataFrame(receipt_data, columns=["File Name", "Store Name", "Date", "Total Amount"])
df.to_excel("receipt_data.xlsx", index=False)  # Save to Excel
print("Receipt data saved to receipt_data.xlsx")
# Out:
# Receipt data saved to receipt_data.xlsx

# %%
# Folder containing images
IMAGE_FOLDER = r"C:\Users\jyoth\Desktop\Adaptive_Schema_Extraction\DATASET\STAGE 1 DATASET\receipts_img"

# List of known store names (can be expanded)
KNOWN_STORES = ["WALMART", "TARGET", "TRADER JOE'S", "COSTCO", "WHOLE FOODS"]

# Function to extract text from an image
def extract_text(image_path):
    image = cv2.imread(image_path)
    gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    text = pytesseract.image_to_string(gray)
    return text

# Function to extract relevant details
def parse_receipt(text):
    lines = text.split("\n")
    store_name = "Not Found"
    total_amount = "Not Found"
    date = "Not Found"

    # Extract store name (Match known stores or uppercase words)
    for line in lines:
        line_clean = re.sub(r'[^a-zA-Z0-9 &]', '', line).strip()
        if any(store in line_clean.upper() for store in KNOWN_STORES):
            store_name = line_clean.upper()
            break
        elif line_clean.isupper() and len(line_clean) > 3 and not re.search(r'survey|feedback|see back', line_clean, re.IGNORECASE):
            store_name = line_clean
            break

    # Extract date (Match multiple formats and choose the first occurrence)
    date_patterns = [
        r'\b\d{1,2}/\d{1,2}/\d{2,4}\b',  # MM/DD/YYYY or MM/DD/YY
        r'\b\d{1,2}-\d{1,2}-\d{2,4}\b',  # DD-MM-YYYY or DD-MM-YY
        r'\b\d{4}-\d{1,2}-\d{1,2}\b'   # YYYY-MM-DD
    ]
    for line in lines:
        for pattern in date_patterns:
            match = re.search(pattern, line)
            if match:
                date = match.group()
                break
        if date != "Not Found":
            break

    # Extract total amount (Look for currency-like values)
    amount_pattern = r'\b\d{1,4}\.\d{2}\b'
    for line in lines:
        if re.search(r'Total|Subtotal', line, re.IGNORECASE):
            match = re.search(amount_pattern, line)
            if match:
                total_amount = match.group()
                break

    return store_name, date, total_amount

# Process all images in the folder
receipt_data = []
for filename in os.listdir(IMAGE_FOLDER):
    if filename.lower().endswith((".png", ".jpg", ".jpeg")):
        image_path = os.path.join(IMAGE_FOLDER, filename)
        text = extract_text(image_path)
        store_name, date, total_amount = parse_receipt(text)
        receipt_data.append([filename, store_name, date, total_amount])

# Save results to Excel
df = pd.DataFrame(receipt_data, columns=["File Name", "Store Name", "Date", "Total Amount"])
df
# Out:
#            File Name                           Store Name        Date  \
# 0              0.jpg                              WALMART   Not Found
# 1              1.jpg                          TRADER JOES  06-28-2014
# 2             10.jpg                            Not Found   Not Found
# 3             11.jpg                                WHOLE   Not Found
# 4             12.jpg                              WALMART     1/20/07
# 5             13.jpg                              WALMART   Not Found
# 6             14.jpg                      ID  7LORX4K8PUX    05/04/17
# 7             15.jpg                            WALMART 7    07/22/16
# 8             16.jpg                      ID  7L2T9WJM25F    11/13/17
# 9             17.jpg                     ID   7K2GF1SL2FF    01/18/17
# 10            18.jpg                            WALMART S    10/31/21
# 11            19.jpg                            WALMART S   Not Found
# 12             2.jpg  GIVE US FEEDBACK  SURVEYWALMART COM    10/18/20
# 13             3.jpg                       TD  7NBN1VIXCO   Not Found
# 14             4.jpg                              WALMART    12/08/15
# 15             5.jpg          KTTL SEA SALT POT CHP 129 F   9/15/2020
# 16             6.JPG                          MOMI & TOYS  26/01/2016
# 17             7.jpg                      ID  7L2T9WJM25F    11/13/17
# 18             8.jpg                E 673919 FF BS BREAST   Not Found
# 19             9.jpg                             BBEST AK    09/08/14
# 20  header_image.jpg                            Not Found   Not Found
#
#    Total Amount
# 0          5.11
# 1     Not Found
# 2     Not Found
# 3     Not Found
# 4         18.75
# 5     Not Found
# 6         26.60
# 7     Not Found
# 8         21.74
# 9         38.68
# 10        86.35
# 11    Not Found
# 12        46.44
# 13    Not Found
# 14         7.43
# 15        28.28
# 16    Not Found
# 17        21.74
# 18         3.52
# 19    Not Found
# 20    Not Found

# %%
# Function to extract text from an image
def extract_text(image_path):
    image = cv2.imread(image_path)
    gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    text = pytesseract.image_to_string(gray)
    return text

# %%
df.to_excel("Extracted_Receipt_Data.xlsx", index=False)

print("Extraction complete! Data saved in Extracted_Receipt_Data.xlsx")
# Out:
# Extraction complete! Data saved in Extracted_Receipt_Data.xlsx
