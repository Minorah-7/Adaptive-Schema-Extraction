# %%
pip install opencv-python numpy
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: opencv-python in c:\users\jyoth\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (4.11.0.86)
# Requirement already satisfied: numpy in c:\users\jyoth\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (1.26.4)
# Note: you may need to restart the kernel to use updated packages.

# %%
# !pip install pytesseract openpyxl
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: pytesseract in c:\users\jyoth\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (0.3.13)
# Requirement already satisfied: openpyxl in c:\users\jyoth\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (3.1.5)
# Requirement already satisfied: packaging>=21.3 in c:\users\jyoth\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from pytesseract) (24.2)
# Requirement already satisfied: Pillow>=8.0.0 in c:\users\jyoth\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from pytesseract) (11.1.0)
# Requirement already satisfied: et-xmlfile in c:\users\jyoth\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (from openpyxl) (2.0.0)

# %%
import pytesseract
pytesseract.pytesseract.tesseract_cmd = r"C:\Program Files\Tesseract-OCR\tesseract.exe"

# %%
pip install tesseract
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: tesseract in c:\users\jyoth\appdata\local\packages\pythonsoftwarefoundation.python.3.12_qbz5n2kfra8p0\localcache\local-packages\python312\site-packages (0.1.3)
# Note: you may need to restart the kernel to use updated packages.

# %%
import cv2
import pytesseract
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
from PIL import Image, ImageDraw

# %%
# Load image using PIL (high quality)
image = Image.open(r"C:\Users\jyoth\Desktop\Adaptive_Schema_Extraction\DATASET\STAGE 1 DATASET\Aadhaar_letter_large.jpeg")

# %%
# Display the image to check clarity
image.show()

# %%
# Convert image to grayscale (PIL handles it better than OpenCV)
gray_image = image.convert("L")  # "L" mode = grayscale

# %%
# Display the grayscale image
gray_image
# Out:
# <PIL.Image.Image image mode=L size=298x717>

# %%
aadhaar_roi = (50, 443, 250, 25)  # (x, y, w, h) - Aadhaar Number
name_roi = (90, 550, 200, 15)     # Name ROI
dob_roi = (130, 565, 100, 15)

# %%
# Create a copy of the image for drawing
image_with_boxes = gray_image.copy()
draw = ImageDraw.Draw(image_with_boxes)

# %%
# Draw rectangles around ROIs
draw.rectangle(
    [aadhaar_roi[0], aadhaar_roi[1], aadhaar_roi[0] + aadhaar_roi[2], aadhaar_roi[1] + aadhaar_roi[3]],
    outline="black", width=3
)
draw.rectangle(
    [name_roi[0], name_roi[1], name_roi[0] + name_roi[2], name_roi[1] + name_roi[3]],
    outline="black", width=3
)
draw.rectangle(
    [dob_roi[0], dob_roi[1], dob_roi[0] + dob_roi[2], dob_roi[1] + dob_roi[3]],
    outline="black", width=3
)

# %%
# Display the image using matplotlib (better for Jupyter Notebook)
plt.figure(figsize=(8, 6))
plt.imshow(image_with_boxes)
plt.axis("off")  # Hide axes
plt.show()

# %%
aadhaar_crop = gray_image.crop((aadhaar_roi[0], aadhaar_roi[1], aadhaar_roi[0] + aadhaar_roi[2], aadhaar_roi[1] + aadhaar_roi[3]))
name_crop = gray_image.crop((name_roi[0], name_roi[1], name_roi[0] + name_roi[2], name_roi[1] + name_roi[3]))

# %%
# Display the image with ROIs
image_with_boxes.show()

# %%
# Perform OCR with specific configs
aadhaar_text = pytesseract.image_to_string(aadhaar_crop, config="--psm 6 -c tessedit_char_whitelist=0123456789")
name_text = pytesseract.image_to_string(name_crop, config="--psm 6")

# %%
# Print results
print("Extracted Aadhaar Number:", aadhaar_text.strip())
print("Extracted Name:", name_text.strip())
# Out:
# Extracted Aadhaar Number: 397788000234
# Extracted Name: ‘Deopak Vasant Surve

# %%
# Function to extract text from an ROI
def extract_text(image, roi):
    x, y, w, h = roi
    cropped = image.crop((x, y, x + w, y + h))  # Crop using PIL
    text = pytesseract.image_to_string(cropped, config="--psm 6").strip()
    return text

# %%
# Extract text from each ROI
aadhaar_number = extract_text(image, aadhaar_roi)
name = extract_text(image, name_roi)

# %%
# Store in a DataFrame
data = {
    "Aadhaar Number": [aadhaar_number],
    "Name": [name]
}
df = pd.DataFrame(data)

# %%
# Save to an Excel file
excel_path = "aadhaar_details.xlsx"  # Change path if needed
df.to_excel(excel_path, index=False)

print(f"✅ Data saved to {excel_path}")
# Out:
# ✅ Data saved to aadhaar_details.xlsx
